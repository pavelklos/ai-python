# %% [markdown]
# #  Data Science 1

# %% [markdown]
# ## Popular Python Data Science Libraries
#
# **Pandas**: A powerful data manipulation library that provides data structures like DataFrames for efficiently working with structured data. It excels at data cleaning, transformation, and analysis with functions for filtering, grouping, merging datasets, and handling missing values.
#
# **Seaborn**: A statistical visualization library built on matplotlib that creates attractive, informative statistical graphics. It offers high-level interfaces for drawing common statistical plots with built-in themes for professional-looking visualizations.
#
# **Bokeh**: An interactive visualization library focused on web-based, interactive plots. It creates JavaScript-powered visualizations that work well in web browsers and notebooks with features like zooming, panning, and hovering for data exploration.
#
# **Key differences between Seaborn and Bokeh**:
#
# - *Purpose*: **Seaborn** focuses on statistical visualization; **Bokeh** specializes in interactive, web-based graphics
# - *Output*: **Seaborn** produces static plots; **Bokeh** creates interactive visualizations
# - *Backend*: **Seaborn** uses matplotlib; **Bokeh** generates JavaScript visualizations
# - *Use case*: **Seaborn** is better for publication-quality statistical charts; **Bokeh** excels at interactive dashboards and web applications

# %% [markdown]
# Short explanation of each package and the differences between **Seaborn** and **Bokeh**:
#
# ### 🔹 `pandas`
# - A data manipulation and analysis library.
# - Works with **DataFrames** (tabular data).
# - Great for cleaning, transforming, and analyzing data before visualization or modeling.
#
# ### 🔹 `seaborn`
# - A statistical data visualization library built on top of **matplotlib**.
# - Ideal for creating static, **publication-quality** charts easily.
# - Good for **exploratory data analysis** with built-in support for DataFrames.
#
# ### 🔹 `bokeh`
# - An interactive visualization library.
# - Designed for **web-based, dynamic plots**.
# - Great for dashboards and apps where **user interaction** (zoom, hover, filter) is important.
#
# ---
#
# ### 🆚 Seaborn vs. Bokeh
#
# | Feature         | Seaborn                          | Bokeh                            |
# |-----------------|----------------------------------|----------------------------------|
# | Type            | Static plots                     | Interactive plots                |
# | Built on        | matplotlib                       | JavaScript (via BokehJS)         |
# | Use case        | Quick EDA, reports               | Dashboards, web apps             |
# | Interactivity   | No                               | Yes (hover, zoom, pan, etc.)     |
# | Output          | Images (PNG, SVG)                | HTML, JavaScript                 |

# %% [markdown]
# ## pandas (powerful data structures for data analysis, time series, and statistics)
# https://pandas.pydata.org/<br>
# https://pandas.pydata.org/docs/<br>
#
# by **DataFrame**<br>
# Powerful Python data analysis toolkit and package that provides fast, flexible, and expressive data structures designed to make working with "relational" or "labeled" data both easy and intuitive.<br>
# It aims to be the fundamental high-level building block for doing practical, real world data analysis in Python.<br>
# Additionally, it has the broader goal of becoming the most powerful and flexible open source data analysis / manipulation tool available in any language.

# %%
import pandas as pd
data_frame = pd.read_csv('data.csv') # type = DataFrame
data_frame.shape
# Out:
# (18207, 89)

# %%
data_frame.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
data_frame.values
# Out:
# array([[0, 158023, 'L. Messi', ..., 14.0, 8.0, '€226.5M'],
#        [1, 20801, 'Cristiano Ronaldo', ..., 14.0, 11.0, '€127.1M'],
#        [2, 190871, 'Neymar Jr', ..., 15.0, 11.0, '€228.1M'],
#        ...,
#        [18204, 241638, 'B. Worman', ..., 6.0, 13.0, '€165K'],
#        [18205, 246268, 'D. Walker-Rice', ..., 8.0, 9.0, '€143K'],
#        [18206, 246269, 'G. Nugent', ..., 12.0, 9.0, '€165K']],
#       shape=(18207, 89), dtype=object)

# %%
data_frame[data_frame["Age"] > 40]
# Out:
#        Unnamed: 0      ID           Name  Age  \
# 1120         1120  156092      J. Villar   41
# 4228         4228    3665       B. Nivet   41
# 4741         4741  140029       O. Pérez   45
# 7225         7225  142998       C. Muñoz   41
# 10545       10545  140183    S. Narazaki   42
# 12192       12192  208927   H. Sulaimani   41
# 15426       15426   18745       M. Tyler   41
# 17726       17726   51963      T. Warner   44
# 18183       18183   53748  K. Pilkington   44
#
#                                                 Photo        Nationality  \
# 1120   https://cdn.sofifa.org/players/4/19/156092.png           Paraguay
# 4228     https://cdn.sofifa.org/players/4/19/3665.png             France
# 4741   https://cdn.sofifa.org/players/4/19/140029.png             Mexico
# 7225   https://cdn.sofifa.org/players/4/19/142998.png          Argentina
# 10545  https://cdn.sofifa.org/players/4/19/140183.png              Japan
# ...

# %%
data_frame["Age"].hist()
# Out:
# <Axes: >

# %%
data_frame.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df1 = pd.DataFrame(data_frame, columns = ['Name', 'Wage', 'Value'])

def value_to_float(x):
    if type(x) == float or type(x) == int:
        return x
    if 'K' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
        return 1000.0
    if 'M' in x:
        if len(x) > 1:
            return float(x.replace('M', '')) * 1000000
        return 1000000.0
    if 'B' in x:
        return float(x.replace('B', '')) * 1000000000
    return 0.0

df1['Wage'] = df1['Wage'].replace('[\€,]', '', regex = True).apply(value_to_float)
df1['Value'] = df1['Value'].replace('[\€,]', '', regex = True).apply(value_to_float)

df1['difference'] = df1['Value'] - df1['Wage']
df1.sort_values('difference', ascending=False)
# Out:
#                Name      Wage        Value   difference
# 2         Neymar Jr  290000.0  118500000.0  118210000.0
# 0          L. Messi  565000.0  110500000.0  109935000.0
# 4      K. De Bruyne  355000.0  102000000.0  101645000.0
# 5         E. Hazard  340000.0   93000000.0   92660000.0
# 15        P. Dybala  205000.0   89000000.0   88795000.0
# ...             ...       ...          ...          ...
# 17672      R. Kawai    1000.0          0.0      -1000.0
# 12192  H. Sulaimani    3000.0          0.0      -3000.0
# 3550    S. Nakamura    4000.0          0.0      -4000.0
# 4228       B. Nivet    5000.0          0.0      -5000.0
# 864          Hilton   18000.0          0.0     -18000.0
#
# [18207 rows x 4 columns]

# %% [markdown]
# ## seaborn (Statistical data visualization)
# https://seaborn.pydata.org/<br>
# Python visualization library based on matplotlib.<br>
# It provides a high-level interface for drawing attractive statistical graphics.

# %%
import seaborn as sns
# sns.set()
sns.set_theme()

graph = sns.scatterplot(x='Wage', y='Value', data=df1)
graph
# Out:
# <Axes: xlabel='Wage', ylabel='Value'>

# %% [markdown]
# ## bokeh (interactive plots and applications in the browser from Python)
# https://bokeh.org/<br>
# https://docs.bokeh.org/en/latest/<br>
# Interactive visualization library for modern web browsers.<br>
# It provides elegant, concise construction of versatile graphics and affords high-performance interactivity across large or streaming datasets.<br>
# Bokeh can help anyone who wants to create interactive plots, dashboards, and data applications quickly and easily.

# %%
from bokeh.plotting import figure,show
from bokeh.models import HoverTool

TOOLTIPS = HoverTool(tooltips=[
    ("index", "$index"),
    ("(Wage,Value)", "(@Wage, @Value)"),
    ("Name", "@Name")]
)

p = figure(title="Soccer 2019", x_axis_label='Wage', y_axis_label='Value',
           # plot_width=700, plot_height=700, tools=[TOOLTIPS])
           width=700, height=700, tools=[TOOLTIPS])
# p.circle('Wage', 'Value', size=10, source=df1)
p.scatter('Wage', 'Value', size=10, source=df1)
show(p)
